# %% [markdown]
# # IMAGE PROCESSING and COMPUTER VISSION

# %%
# IMAGE PROCESSING and COMPUTER VISSION
# Range 8 bit :-0 to 255
# image types:
# # 1.true color image use by color strength RGB , CMYK ,HSV
# 2.Gray scale :::>>this are use for small resolution
# 3.Binary

# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img=cv2.imread('download.JPEG')
cv2.imshow('like',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (270, 325, 3)

# %%
img
# Out:
# array([[[175, 197, 239],
#         [175, 197, 239],
#         [174, 196, 238],
#         ...,
#         [171, 193, 235],
#         [171, 193, 235],
#         [171, 193, 235]],
#
#        [[174, 196, 238],
#         [174, 196, 238],
#         [173, 195, 237],
#         ...,
#         [171, 193, 235],
#         [171, 193, 235],
#         [171, 193, 235]],
#
#        [[172, 194, 236],
#         [172, 194, 236],
#         [171, 193, 235],
#         ...,
#         [170, 192, 234],
#         [170, 192, 234],
#         [170, 192, 234]],
#
#        ...,
#
#        [[170, 192, 234],
#         [170, 192, 234],
#         [170, 192, 234],
#         ...,
#         [170, 192, 234],
#         [170, 192, 234],
#         [170, 192, 234]],
#
#        [[171, 193, 235],
#         [171, 193, 235],
#         [171, 193, 235],
#         ...,
#         [171, 193, 235],
#         [171, 193, 235],
#         [171, 193, 235]],
#
#        [[175, 197, 239],
#         [175, 197, 239],
#         [175, 197, 239],
# ...

# %%
img1=plt.imread('download.jpeg')
plt.imshow(img1)

# %%
plt.bar(55,5,5)
# Out:
# <BarContainer object of 1 artists>
